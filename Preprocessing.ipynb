# %%
from nltk.tokenize import sent_tokenize, word_tokenize, wordpunct_tokenize
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory
import pandas as pd
import string

# %%
raw_data_1 = pd.read_csv("./LPSE LKPP + pemenang.csv")

raw_data_1.head(100)
# Out:
#        kode                                        nama_tender  \
# 0   6599119  Tenaga Ahli Data Driven Kegiatan Koordinasi Se...
# 1   6598119  Tenaga Ahli IT Analisa Sistem   Kegiatan Koord...
# 2   6597119  Tenaga Ahli Senior Monitoring dan Evaluasi Str...
# 3   6596119  Tenaga Ahli Senior Perencanaan Strategic Natio...
# 4   6595119  Tenaga Ahli Muda Bidang Energy Policy Kegiatan...
# ..      ...                                                ...
# 95  6420119            Pengadaan Generator Set 100 Kva / 80 Kw
# 96  6419119  Pengadaan Gate Valve Tahun 2019 <span class='l...
# 97  6418119  Management Pressur Jaringan Distribusi <span c...
# 98  6417119  Pengadaan Pemancar FM 1 KW + Antena + Coaxcial...
# 99  6415119                       Pengadaan COntent Server DRM
#
#                                         instansi  \
# 0   Kementerian Perencanaan Pembangunan Nasional
# 1   Kementerian Perencanaan Pembangunan Nasional
# 2   Kementerian Perencanaan Pembangunan Nasional
# 3   Kementerian Perencanaan Pembangunan Nasional
# 4   Kementerian Perencanaan Pembangunan Nasional
# ..                                           ...
# 95                             PDAM Tirta Moedal
# 96             PDAM Tirta Aji Kabupaten Wonosobo
# 97             PDAM Tirta Aji Kabupaten Wonosobo
# 98    Lembaga Penyiaran Radio Republik Indonesia
# 99    Lembaga Penyiaran Radio Republik Indonesia
#
#                         status_tender       hps                           5  \
# 0   Pengumuman Pascakualifikasi [...]    120 Jt   Pascakualifikasi Dua File
# 1   Pengumuman Pascakualifikasi [...]  183,5 Jt   Pascakualifikasi Dua File
# 2   Pengumuman Pascakualifikasi [...]  228,4 Jt   Pascakualifikasi Dua File
# 3   Pengumuman Pascakualifikasi [...]  254,1 Jt   Pascakualifikasi Dua File
# 4   Pengumuman Pascakualifikasi [...]    132 Jt   Pascakualifikasi Dua File
# ..                                ...       ...                         ...
# 95               Tender Sudah Selesai    335 Jt  Pascakualifikasi Satu File
# 96               Tender Sudah Selesai  316,3 Jt  Pascakualifikasi Satu File
# 97               Tender Sudah Selesai    468 Jt  Pascakualifikasi Satu File
# 98               Tender Sudah Selesai  728,9 Jt  Pascakualifikasi Satu File
# 99               Tender Sudah Selesai  356,4 Jt  Pascakualifikasi Satu File
#
#                6                            7  \
# 0        Seleksi                     Kualitas
# 1        Seleksi                     Kualitas
# 2        Seleksi                     Kualitas
# 3        Seleksi                     Kualitas
# 4        Seleksi                     Kualitas
# ..           ...                          ...
# 95  Tender Cepat  Harga Terendah Sistem Gugur
# 96  Tender Cepat  Harga Terendah Sistem Gugur
# 97  Tender Cepat  Harga Terendah Sistem Gugur
# 98        Tender  Harga Terendah Sistem Gugur
# 99        Tender  Harga Terendah Sistem Gugur
#
#                                         8  9  ...  11  12  13  \
# 0   Jasa Konsultansi Perorangan - TA 2020  3  ... NaN NaN   0
# 1   Jasa Konsultansi Perorangan - TA 2020  3  ... NaN NaN   0
# 2   Jasa Konsultansi Perorangan - TA 2020  3  ... NaN NaN   0
# 3   Jasa Konsultansi Perorangan - TA 2020  3  ... NaN NaN   0
# 4   Jasa Konsultansi Perorangan - TA 2020  3  ... NaN NaN   0
# ..                                    ... ..  ...  ..  ..  ..
# 95             Pengadaan Barang - TA 2019  3  ... NaN NaN   0
# 96             Pengadaan Barang - TA 2019  3  ... NaN NaN   0
# 97             Pengadaan Barang - TA 2019  3  ... NaN NaN   0
# 98             Pengadaan Barang - TA 2019  3  ... NaN NaN   0
# 99             Pengadaan Barang - TA 2019  3  ... NaN NaN   0
#
#             kategori               pagu         hps_detail  \
# 0                NaN                NaN                NaN
# 1                NaN                NaN                NaN
# 2                NaN                NaN                NaN
# 3                NaN                NaN                NaN
# 4                NaN                NaN                NaN
# ..               ...                ...                ...
# 95  Pengadaan Barang  Rp 375.375.000,00  Rp 335.038.000,00
# 96  Pengadaan Barang  Rp 316.564.600,00  Rp 316.322.875,00
# 97  Pengadaan Barang  Rp 468.120.400,00  Rp 467.996.100,00
# 98  Pengadaan Barang  Rp 729.402.000,00  Rp 728.900.000,00
# 99  Pengadaan Barang  Rp 364.029.000,00  Rp 356.430.800,00
#
#             nama_pemenang                                    alamat_pemenang  \
# 0                     NaN                                                NaN
# 1                     NaN                                                NaN
# 2                     NaN                                                NaN
# 3                     NaN                                                NaN
# 4                     NaN                                                NaN
# ..                    ...                                                ...
# 95        MITRA NUSANTARA  Jalan Cakra I No.22 RT.1 RW.18 Cokrowijayan Ba...
# 96   PT.TRISUKSES PERMATA  Kirana Two Building lt 10 - A Jalan Boulevard ...
# 97   PT.TRISUKSES PERMATA  Kirana Two Building lt 10 - A Jalan Boulevard ...
# 98  PT. GITA MENATA INDAH  JL. UTAN KAYU RAYA, NO. 63, RT. 011/005, KEL. ...
# 99  CV. DIAN INTI PRATAMA  KO. RINDU SERUMPUN VII NO.1 JL. RAJAWALI SAKTI...
#
#            npwp_pemenang penawaran_pemenang
# 0                    NaN                NaN
# 1                    NaN                NaN
# 2                    NaN                NaN
# 3                    NaN                NaN
# 4                    NaN                NaN
# ..                   ...                ...
# 95  01.464.445.4-542.000  Rp 305.789.000,00
# 96  75.555.231.2-043.000  Rp 315.099.191,00
# 97  75.555.231.2-043.000  Rp 459.923.836,90
# 98  71.713.274.0-008.000  Rp 710.160.000,00
# 99  90.252.873.6-216.000  Rp 349.800.000,00
#
# [100 rows x 21 columns]

# %%
factory = StopWordRemoverFactory()
stopwords = factory.get_stop_words()

# %%
result_preprocessing = []
for column in raw_data_1['nama_tender']:
    sentence = column.lower()
    word = word_tokenize(text = sentence)
    result_remove_punctuation = [result for result in word if result not in list(string.punctuation)]
    result_remove_stopwords = [result for result in result_remove_punctuation if not result in stopwords]
    result_remove_stopwords = ' '.join(result_remove_stopwords)
    result_preprocessing.append(result_remove_stopwords)

# %%
raw_data_1['preprocessing'] = result_preprocessing

# %%
raw_data_1.to_csv("Preprocessing.csv",index=False)
